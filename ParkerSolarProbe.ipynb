# %%
import pyspedas
from pytplot import tplot
fields_vars = pyspedas.psp.fields(trange=['2021-11-20', '2021 -11-22'], datatype='mag_rtn', level='l2', time_clip=True)
tplot('psp_fld_l2_mag_RTN')
# Out:
# 02-Sep-22 12:20:31: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l2/mag_rtn/2021/
# 02-Sep-22 12:20:32: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l2/mag_rtn/2021/psp_fld_l2_mag_rtn_2021112000_v02.cdf to psp_data/fields/l2/mag_rtn/2021/psp_fld_l2_mag_rtn_2021112000_v02.cdf
# 02-Sep-22 12:20:41: Download complete: psp_data/fields/l2/mag_rtn/2021/psp_fld_l2_mag_rtn_2021112000_v02.cdf
# 02-Sep-22 12:20:41: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l2/mag_rtn/2021/psp_fld_l2_mag_rtn_2021112006_v02.cdf to psp_data/fields/l2/mag_rtn/2021/psp_fld_l2_mag_rtn_2021112006_v02.cdf
# 02-Sep-22 12:20:51: Download complete: psp_data/fields/l2/mag_rtn/2021/psp_fld_l2_mag_rtn_2021112006_v02.cdf
# 02-Sep-22 12:20:51: Downloading https://spdf.gsfc.nasa.gov/pub/data/psp/fields/l2/mag_rtn/2021/psp_fld_l2_mag_rtn_2021112012_v02.cdf to psp_data/fields/l2/mag_rtn/2021/psp_fld_l2_mag_rtn_2021112012_v02.cdf
# ...

# %%
tplot('psp_fld_l2_mag_RTN')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 tplot('psp_fld_l2_mag_RTN')
#
# File ~/pyspedas/lib/python3.8/site-packages/pytplot/tplot.py:158, in tplot(name, var_label, slice, combine_axes, nb, save_file, gui, qt, bokeh, save_png, display, testing, extra_functions, extra_function_args, vert_spacing, pos_2d, pos_3d, exec_qt, window_name, interactive, xsize, ysize, save_eps, save_svg, save_pdf, fig, axis, pseudo_plot_num, second_axis_size, return_plot_objects)
#      75 """
#      76 This is the function used to display the tplot variables stored in memory.
#      77 The default output is to show the plots stacked on top of one another inside of a qt window
#    (...)
#     154     >>> div, component = pytplot.tplot(["Variable1", "Variable2", "Variable3"], gui=True)
#     155 """
#     157 if qt == False and bokeh == False:
# ...
